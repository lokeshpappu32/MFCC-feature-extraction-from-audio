# %%
import os
import pandas as pd

features = {}
directory = 'C:/Users/surya/Desktop/NIT WARANGAL/voice dataset-20230529T122838Z-001/Mozilla Dataset Adult/Female/'
output_filename = 'Adult_Female_mfcc_Features.csv'

for index, audio in enumerate(os.listdir(directory)):
    audio_path = os.path.join(directory, audio)
    features[audio_path] = feature_extraction(audio_path)
    print(features[audio_path])
    df = pd.DataFrame(features[audio_path])
    df.columns = [f'mfcc_{index}']  # Set column name based on index
    df = df.T  # Transpose the DataFrame
    if index == 0:
        combined_df = df
    else:
        combined_df = pd.concat([combined_df, df])
# Add extra columns for gender and label
combined_df['gender'] = 'female'  # Assuming all files are from females
combined_df['label'] = 'adult'  # Assuming the label is 'adult'

# Save the combined DataFrame to a CSV file
combined_df.to_csv(output_filename, index=False)
# Out:
# [-4.8921234e+02  7.2674286e+01 -2.4952650e+00  9.6863937e+00
#   4.1113429e+00 -9.5420599e+00 -2.9492264e+01 -8.2346144e+00
#  -2.9791945e+01 -7.5701475e+00 -2.0507803e+01 -3.2315331e+00
#  -1.1977867e+01 -2.2369514e+00 -5.5613747e+00 -4.0298047e+00
#  -4.3797474e+00 -7.2690110e+00 -5.8734326e+00 -7.7375498e+00
#  -6.1871686e+00 -5.2743049e+00 -3.3098364e+00 -5.6498332e+00
#  -1.8446760e+00 -1.7596853e+00  1.2930466e+00 -1.1318192e+00
#   2.1952720e+00  3.2331383e+00  1.3372166e+00  1.3622971e+00
#   2.3472900e+00 -1.4971826e+00 -1.1724110e+00  2.8024209e-01
#  -2.9260297e+00 -2.3284371e+00 -9.1618264e-01]
# [-4.3088556e+02  7.7972084e+01 -1.9552436e+00  2.8332274e+00
#   8.0817914e-01 -1.2826048e+01 -3.6226223e+01 -1.4434361e+01
#  -3.5166103e+01 -2.0774024e+00 -2.6497778e+01 -3.8848708e+00
#  -1.0598374e+01 -3.4097164e+00 -9.1012135e+00 -3.8051279e+00
#  -5.6011648e+00 -7.8519201e+00 -8.9884501e+00 -6.8083429e+00
#  -7.6457744e+00 -5.0296741e+00 -3.4153388e+00 -1.6600617e+00
# ...

# %%
def feature_extraction(file_path):
    x,sample_rate=librosa.load(file_path,res_type='kaiser_fast')
    mfcc=np.mean(librosa.feature.mfcc(y=x,sr=sample_rate,n_mfcc=39).T,axis=0)
    return mfcc

# %%
import librosa
import librosa.display
import IPython.display as ipd
import numpy as np
import csv
import pandas as pd
import os

# %%
import os
import pandas as pd

features = {}
directory = 'C:/Users/surya/Desktop/NIT WARANGAL/voice dataset-20230529T122838Z-001/Mozilla Dataset Adult/Male/'
output_filename = 'Adult_Male_mfcc_Features.csv'

for index, audio in enumerate(os.listdir(directory)):
    audio_path = os.path.join(directory, audio)
    features[audio_path] = feature_extraction(audio_path)
    print(features[audio_path])
    df = pd.DataFrame(features[audio_path])
    df.columns = [f'mfcc_{index}']  # Set column name based on index
    df = df.T  # Transpose the DataFrame
    if index == 0:
        combined_df = df
    else:
        combined_df = pd.concat([combined_df, df])
# Add extra columns for gender and label
combined_df['gender'] = 'male'  # Assuming all files are from females
combined_df['label'] = 'adult'  # Assuming the label is 'adult'

# Save the combined DataFrame to a CSV file
combined_df.to_csv(output_filename, index=False)
# Out:
# [-3.7182809e+02  1.0849565e+02  1.1329577e+01  2.2444441e+01
#   2.2374722e+01  5.6896391e+00 -5.8203821e+00 -1.9522390e+00
#  -1.6463146e+01  6.0614181e+00 -6.4415674e+00  2.9539568e+00
#  -1.1599416e+01  4.0575523e+00 -3.8680348e+00 -2.4944367e+00
#  -5.6207871e+00 -1.2524177e+00 -7.9837828e+00  2.2087481e+00
#  -7.6231804e+00 -9.1362822e-01 -5.0008454e+00 -2.5140824e+00
#  -5.4006348e+00 -2.1928327e+00 -5.0902319e+00 -3.1133785e+00
#  -4.6684780e+00 -1.8462315e-01 -2.0575500e+00 -2.3832722e+00
#  -1.0471495e+00 -5.1130095e+00 -3.6501167e+00 -3.0925906e+00
#  -1.9557765e+00 -4.4050603e+00 -4.5809903e+00]
# [-3.9931082e+02  1.1292151e+02  6.9191723e+00  2.1663918e+01
#   1.8155872e+01  7.1817579e+00 -1.5186312e+00  5.8183211e-01
#  -1.8784006e+01  3.9096777e+00 -5.0960946e+00  6.3219323e+00
#  -8.4601269e+00  1.8406266e+00 -3.6655757e+00 -1.8221083e+00
#  -7.9661913e+00  7.5092405e-01 -8.4196978e+00 -1.4855204e+00
#  -6.5453577e+00  7.7504396e-01 -6.8507776e+00  3.4407946e-01
# ...

# %%
import os
import pandas as pd

features = {}
directory = 'C:/Users/surya/Desktop/NIT WARANGAL/voice dataset-20230529T122838Z-001/Dataset Child/Male'
output_filename = 'Child_Male_mfcc_Features.csv'

for index, audio in enumerate(os.listdir(directory)):
    audio_path = os.path.join(directory, audio)
    features[audio_path] = feature_extraction(audio_path)
    print(features[audio_path])
    df = pd.DataFrame(features[audio_path])
    df.columns = [f'mfcc_{index}']  # Set column name based on index
    df = df.T  # Transpose the DataFrame
    if index == 0:
        combined_df = df
    else:
        combined_df = pd.concat([combined_df, df])
# Add extra columns for gender and label
combined_df['gender'] = 'male'  # Assuming all files are from females
combined_df['label'] = 'child'  # Assuming the label is 'adult'

# Save the combined DataFrame to a CSV file
combined_df.to_csv(output_filename, index=False)
# Out:
# [-254.649        79.42945     -22.592579     64.86672     -49.41248
#    -1.9964553   -29.40174     -16.42495     -11.666932    -16.654684
#    -3.9830117   -23.46856      -8.816263     -5.3866777    -3.6396978
#   -13.9669075    -8.147159    -10.226561    -12.20726      -8.143168
#    -9.960152    -10.82049      -9.158654     -1.0954213    -1.7164252
#     8.079211     12.038863     13.751665     11.303211      1.3479002
#    -4.531345     -2.5058563    -1.2906452    -0.5846946     0.43359396
#    -5.292261     -3.8733675    -3.1483274     1.9106561 ]
# [-2.59457947e+02  5.62441368e+01 -3.29980240e+01  4.74871140e+01
#  -4.31264534e+01 -1.10587282e+01 -2.87674599e+01 -1.62717724e+01
#  -1.54043970e+01 -2.03334064e+01 -1.33307219e+00 -8.62787342e+00
#  -1.81037277e-01 -6.59409523e+00 -6.04402256e+00 -8.39986992e+00
#  -5.47039843e+00 -1.09378605e+01 -1.35475140e+01 -3.04545188e+00
#  -2.28610897e+00 -1.79025367e-01  6.83094931e+00  7.96760941e+00
# ...

# %%
import os
import pandas as pd

features = {}
directory = 'C:/Users/surya/Desktop/NIT WARANGAL/voice dataset-20230529T122838Z-001/Dataset Child/Female'
output_filename = 'Child_Female_mfcc_Features.csv'

for index, audio in enumerate(os.listdir(directory)):
    audio_path = os.path.join(directory, audio)
    features[audio_path] = feature_extraction(audio_path)
    print(features[audio_path])
    df = pd.DataFrame(features[audio_path])
    df.columns = [f'mfcc_{index}']  # Set column name based on index
    df = df.T  # Transpose the DataFrame
    if index == 0:
        combined_df = df
    else:
        combined_df = pd.concat([combined_df, df])
# Add extra columns for gender and label
combined_df['gender'] = 'female'  # Assuming all files are from females
combined_df['label'] = 'child'  # Assuming the label is 'adult'

# Save the combined DataFrame to a CSV file
combined_df.to_csv(output_filename, index=False)
# Out:
# [-3.06166290e+02  8.89349289e+01  4.65505302e-01  2.76481247e+01
#  -3.88580246e+01 -1.95894661e+01 -9.17682934e+00 -2.93041077e+01
#  -1.12872286e+01 -2.62371945e+00 -2.03265762e+00 -1.51546490e+00
#   2.72388768e+00 -7.48985958e+00 -9.01217079e+00 -8.67425859e-01
#  -9.61476898e+00 -6.48427916e+00 -8.21224403e+00 -9.26733875e+00
#  -8.53704453e+00 -7.24670362e+00 -2.52889681e+00  9.48133171e-01
#   1.08495264e+01  1.14137125e+01  1.02859945e+01  1.03599215e+01
#  -1.88353956e+00 -1.49850142e+00  8.49568188e-01  5.50083101e-01
#   6.22514725e+00  1.56514788e+00 -2.18804073e+00 -5.44130147e-01
#   1.36686280e-01  1.02276278e+00 -1.02458823e+00]
# [-3.3043152e+02  8.6511719e+01 -1.0862547e+01  2.3816563e+01
#  -3.5556164e+01 -7.6707354e+00 -9.1566439e+00 -2.8827955e+01
#  -4.1594353e+00  6.9474274e-01 -5.3431711e+00 -1.9256996e+00
#   2.8908935e+00 -1.0012239e+01 -1.2811757e+01 -1.2364558e+00
#  -7.4478555e+00 -3.5013108e+00 -8.4087439e+00 -5.6096339e+00
# ...
